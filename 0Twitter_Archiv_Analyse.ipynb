# %% [markdown]
# # Analyse Twitter Archiv

# %% [markdown]
# Gliederung:
#
# - Imports
# - Funktionen
#     - Vorbereitung
#     - Analyse Aktivität
#     - Analyse Inhalte
# - Resultate
#     - Patrick Karpiczenko (Comedian)
#     - Andri Silberschmidt (Politiker)
#     - Patrizia Laeri (Journalistin)
#     - Emma Hodcroft (Virologin)
# - Quellen
# - Appendix

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
import os, re, sys

# %%
import datetime, pytz, json
from dateutil.tz import tzlocal

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.patches as patches
import matplotlib.path as path
import matplotlib.cm as cm

from collections import Counter

from nltk.cluster import GAAClusterer
import nltk.corpus
from nltk import decorators
import nltk.stem

# %% [markdown]
# ## Funktionen

# %% [markdown]
# ### Vorbereitung

# %% [markdown]
# #### Tweets laden

# %%
def load_tweets_from_js(js_file):
    with open(js_file, "r") as f:
        data = f.read()
        data = data.replace("window.YTD.tweets.part0 = ", "")
        tweets = json.loads(data)
        for tweet in tweets:
            ts = datetime.datetime.strptime(
                tweet["tweet"]["created_at"], "%a %b %d %H:%M:%S +0000 %Y"
            )
            ts = ts.replace(tzinfo=pytz.utc)
            ts = ts.astimezone(tzlocal())
            tweet["timestamp"] = ts
        print("Loaded %d tweets" % len(tweets))
        return tweets

# %% [markdown]
# ####  Dictionary bauen, das die genutzten Daten extrahiert aus dem Twitter-Json

# %%
def create_custom_dictionary(tweets, keys_list):
    """
    in: tweets (created by load_tweets_from_json), and keys_list 
    (has to be listed by hand: which dict values 
    should appear in the custom dict as well, in order to be analyzed later?
    """
    
    tweet_dict = {key:[] for key in keys_list}
    
    # populates Dictionary of Tweets with the important values, as listed in Keys_list
    for item in tweets:
    
        for key in keys_list:
            value = item["tweet"].get(key)
            tweet_dict[key].append(value)

            
    # Zwei neue Keys im Dictionary angelegt für Reply und Retweet (T/F)
    tweet_dict['reply'] = []
    tweet_dict['retweet'] = []
    
    
    # Keys befüllt mit (T/F für Retweet oder Reply)
    for item in tweet_dict["full_text"]:
        reply = item.startswith("@")
        tweet_dict["reply"].append(reply)
        retweet = item.startswith("RT")
        tweet_dict["retweet"].append(retweet)
        
    
    return tweet_dict

# %% [markdown]
# #### Dataframe bauen aus den Tweets

# %%
def create_pandas_dataframe(tweet_dict):
    
    """
    In: tweet_dict (the custom dictionary with keys_list entries created with create_custom_dictionary)
    Out: a clean dataframe with these values
        index set to datetime
        additional column orig which is TRUE if it is neither reply nor retweet
    """
    
    df = pd.DataFrame(tweet_dict)
    
    # Strings in Integers umwandeln, nach Spalte 
    df["favorite_count"]= df['favorite_count'].astype(int)
    df["retweet_count"]= df['retweet_count'].astype(int)

    # Dataframe sortieren nach Datum (über DateTime)
    df["datetime"] = pd.to_datetime(df["created_at"])
    df = df.sort_values("datetime")
    
    # Index in Datetime ändern, andere Date-Spalten droppen
    df.index = pd.to_datetime(df.datetime)
    df = df.drop(['created_at', 'datetime'], axis=1)
    
    
    #Neue Spalte für "orig"inale Tweets, die weder Reply oder Retweet sind
    df["orig"] = np.where( (df['reply']== False ) & (df["retweet"]== False), True, False)
    
    return df

# %% [markdown]
# ### Analyse Aktivität

# %% [markdown]
# #### Verschiedene Analysen des Dataframes, Tabellen und Plots werden gespeichert

# %%
def analysis_and_save(df,name):
    """
    Function to save overview_dataframe and analysis lists and pictures

    In: df, as produced by create_pandas_dataframe and name of the person tweeting
    
    
    Out: (all names beginning with name of person)
        csv:
            - df
            - tweets_per_month
            - tweets_per_day
            - top tweets 
            
            
         plots:
            - tweets_per_month_figure
            - tweets_per_day_figure 
            - tweets_per_day_overall: Grafik mit 5 subplots für Tweets, Retweets, Replies, N°Likes, N°retweets
    
    """
    # First, Dataframes of aggregates/Top10 are created
    
    tweets_per_month = df.groupby(pd.Grouper(freq='M')).sum() 
    tweets_per_day = df.groupby(pd.Grouper(freq='d')).sum()
    top10_retweet_count = df.sort_values('retweet_count', ascending=False).head(10)
    top10_favorite_count = df.sort_values('favorite_count', ascending=False).head(10)
    
    # Then, all of them are saved as CSV files
    
    df.to_csv(str(name)+'_tweetlist.csv') 
  
    tweets_per_month.to_csv(str(name)+"_tweets_per_month.csv")
    tweets_per_day.to_csv(str(name)+"_tweets_per_day.csv")
    top10_retweet_count.to_csv(str(name)+"_top10_retweet_count.csv")
    top10_favorite_count.to_csv(str(name)+"_top10_favorite_count.csv")
    
    
    # Then, plots are created from these dataframes and saved, as png, could be changed into pdf or others
    
    tweets_per_month_figure = tweets_per_month.plot(title="Tweets pro Monat").get_figure()
    tweets_per_month_figure.savefig(str(name)+"_tweets_per_month_figure.png")
     
    tweets_per_day_figure = tweets_per_day.plot(title="Tweets pro Tag").get_figure()
    tweets_per_day_figure.savefig(str(name)+"_tweets_per_day_figure.png")
    
    # Zusammenfassungs-Figure, vielleicht wäre die allein genug
    
    tweets_per_day_overall = tweets_per_day.plot(subplots=True, layout=(3,2), figsize = (12,12), title="Tweets_Tag_alle_Typen")
    plt.savefig(str(name)+"_tweets_per_day_5in1_figure.png")

# %% [markdown]
# #### Tweets nach Day of Week und Time of Day - Darstellung über die Zeit hinweg als Heatmap

# %%
def dataframe_days_months_heatmap(tweets):
    
    """
    Eine Heatmap der Tweet-Aktivitäten, zusammengefasst nach Monat/Jahr, zb. 2022-01, 2022-02, etc.
    - für jeden Monat sieht man, was die aktivisten Wochentage waren
    
    
    
    In: tweets einer Person
    Out: Pandas heatmap wird angezeigt (nicht gespeichert)
    
    """
    
    data = {}
    dow = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]

    for tweet in tweets:
        weekday = tweet["timestamp"].strftime("%A") # extracts weekday
        iso_yr, iso_wk, iso_wkday = tweet["timestamp"].isocalendar()
        # key = str(iso_yr) + "-" + str(iso_wk)
        key = tweet["timestamp"].strftime("%Y-%m")
        if key not in data:
            data[key] = Counter()
            
#Counter is an unordered collection where elements are stored as Dict keys and their count as dict value. 
#Counter elements count can be positive, zero or negative integers. 
            
        else: 
            data[key][weekday] += 1
    #print(json.dumps(data, indent=2))
    
    
    xx = pd.DataFrame(data)
    xx = xx.transpose()
    xx = xx.sort_index(axis=0)
    xx = xx[["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]]
    xx = xx.fillna(0)
    xx = xx.astype(int)
    return xx.style.background_gradient(cmap='coolwarm')

# %%
def dataframe_hours_months_heatmap(tweets):
    
    """
    Eine Heatmap der Tweet-Aktivitäten, zusammengefasst nach Monat/Jahr, zb. 2022-01, 2022-02, etc.
    - für jeden Monat sieht man, was die aktivisten Wochentage waren
    
    
    
    In: tweets einer Person
    Out: Pandas heatmap wird angezeigt (nicht gespeichert)
    
    """
    
    # Get the # hour for each tweet
    data = {}
    #hours = []
    #for tweet in tweets:
    #    hours.append(tweet["timestamp"].hour) # macht eine lange liste mit Stunde je Tweet
        
    months = {}
    for tweet in tweets:
        hour = tweet["timestamp"].strftime("%H") # extracts hour
        #iso_yr, iso_wk, iso_wkday = tweet["timestamp"].isocalendar()
        # key = str(iso_yr) + "-" + str(iso_wk)
        key = tweet["timestamp"].strftime("%Y-%m")
        if key not in months:
            months[key] = Counter()
        else: 
            months[key][hour] += 1
            
#Counter is an unordered collection where elements are stored as Dict keys and their count as dict value. 
#Counter elements count can be positive, zero or negative integers. 
            
    #print(json.dumps(data, indent=2))
    
    xx = pd.DataFrame(months)
    xx = xx.transpose().sort_index(axis=0)
    xx = xx.reindex(sorted(xx.columns), axis=1)
    xx = xx.fillna(0).astype(int)
    xx.style.background_gradient(cmap='coolwarm')
    return xx.style.background_gradient(cmap='coolwarm')

# %% [markdown]
# ### Auswertung Inhalte

# %% [markdown]
# ##### Vorbereitung Stopwords-Filter für DE und EN

# %%
stopworte = nltk.corpus.stopwords.words('german')
stopwords = nltk.corpus.stopwords.words('english')

# %%
stopwords.append('https') # weitere könnte man ausschliessen
stopwords.append('http')

# %%
stopwort_zusatz = ["schon","mehr","beim","wieso","nein","wurde","warum","seit"]

# %%
stopworte = stopworte + stopwort_zusatz

# %% [markdown]
# ##### Hilfsfunktionen

# %%
def get_users(tweets):
    """
    In: tweets_[name], as from load_tweets_from_js
    
    Out:get list of all the users this person mentions in her tweets and retweets, lowercase, without @

    """
    
    all_users = []
    for tweet in tweets:
        for user in re.findall("@\w+", tweet["tweet"]["full_text"]):
            all_users.append(user)
    all_users = set(all_users)
    all_users = [y.replace('@', '') for y in all_users]
    all_users = [y.lower() for y in all_users]

    return(all_users)

# %%
def get_hashtags(tweets):
    """
    In: tweets_[name], as from load_tweets_from_js
    
    Out:get list of all the users this person mentions in her tweets and retweets, lowercase, without @

    """
    
    all_hashtags = []
    for tweet in tweets:
        for hashtag in re.findall("\#[\d\w]+", tweet["tweet"]["full_text"]):
            all_hashtags.append(hashtag)
    all_hashtags = set(all_hashtags)
    all_hashtags = [y.replace('#', '') for y in all_hashtags]
    all_hashtags = [y.lower() for y in all_hashtags]

    return(all_hashtags)

# %%
def get_words(tweet_text):
    """
    in: string - out: all words with more than 3 letters, no unusual characters/numbers 
    """
    return [word.lower() for word in re.findall("\w+", tweet_text) if len(word) > 3]

# %% [markdown]
# #### Funktionen, um die meistgenutzten Worte, Hashtags und Users zu sammeln und als Histogramm zu plotten

# %%
def count_and_plot_top50words(name, tweets):
    """
    in: tweet-sammlung, name als string, out: csv der top50worte - und histogramm 
    voraussetzung: stopwords, stopworte, get_words
    
    diese Funktion extrahiert die Tweets aus dem Ursprungs-dict. Dann zählt sie die Wörter (Filter Stopwords und
    @Users.)
    

    Dann macht sie aus den häufisten Wörtern ein Histogramm
    
    Im Moment top 50, könnten aber auch mehr sein
    
    """
    
    c = Counter() #general words
    #hash_c = Counter() # hashtags
    #at_c = Counter() #replies to 
    
    all_users = []
    for tweet in tweets:
        for user in re.findall("@\w+", tweet["tweet"]["full_text"]):
            all_users.append(user)
    all_users = set(all_users)
    all_users = [y.replace('@', '') for y in all_users]
    #return(all_users)
    
    for tweet in tweets:
        for word in get_words(tweet["tweet"]["full_text"]):
            if word not in stopwords:
                if word not in stopworte:
                    if word not in all_users:
                        c[word] += 1

    
    counter50words = c.most_common(50)
    #counter50hashtags = hash_c.most_common(50)
    #counter50users = at_c.most_common(50)

    top50words = pd.DataFrame(counter50words) 
    top50words.rename(columns={0:"Worte", 1:"Häufigkeit"}, inplace=True)
    top50words.set_index("Worte", inplace=True)
    top50words.to_csv(str(name)+"_top50words.csv")
    
    
       # Ab hier die Plots
    
    ## Words
    words = list(zip(*counter50words))[0] # Word
    counters = list(zip(*counter50words))[1] # Counter
    x_pos = np.arange(len(words)) 
    
    plt.bar(x_pos, counters,align='center')
    plt.xticks(x_pos, words,rotation='vertical', fontsize=6) 
   # plt.figure(figsize=(15, 20))
    plt.savefig(str(name)+'_top50words.png')

# %%
def count_and_plot_top50hashtags(name, tweets):
    """
    in: tweet-sammlung, name als string, out: csv der top50hashtags - und histogramm 
    voraussetzung: stopwords, stopworte, get_words
    
    diese Funktion extrahiert die Tweets aus dem ursprungs-dict. Dann zählt sie die Wörter (Filter Stopwords)

    Dann macht sie aus den häufisten Hashtags ein Histogramm
    
    
    Im Moment top 50, könnten aber auch mehr sein

    
    """
    
    hash_c = Counter() # hashtags
   
    
    
    for tweet in tweets:
   
        for word in re.findall("\#[\d\w]+", tweet["tweet"]["full_text"]):
            hash_c[word.lower()] += 1
    
    counter50hashtags = hash_c.most_common(50)
    top50hashtags = pd.DataFrame(counter50hashtags) 
    top50hashtags.rename(columns={0:"Hashtag", 1:"Häufigkeit"}, inplace=True)
    top50hashtags.set_index("Hashtag", inplace=True)
    top50hashtags.to_csv(str(name)+"_top50hashtags.csv")

    
    #PLOT
    
    ## Words
    words = list(zip(*counter50hashtags))[0] # Word
    counters = list(zip(*counter50hashtags))[1] # Counter
    x_pos = np.arange(len(words)) 
    
    plt.bar(x_pos, counters,align='center')
    plt.xticks(x_pos, words,rotation='vertical', fontsize=6) 
   # plt.figure(figsize=(15, 20))
    plt.savefig(str(name)+'_top50hashtags.png')

# %%
def count_and_plot_top50users(name, tweets):
    """
    in: tweet-sammlung, name als string, out: csv der top50user - und histogramm 
    voraussetzung: stopwords, stopworte, get_words
    
    diese Funktion extrahiert die Tweets aus dem ursprungs-dict. Dann zählt sie die Wörter (Filter Stopwords.)

    Dann macht sie aus den häufist genannten Nutzern ein Histogramm
    
    Im Moment top 50, könnten aber auch mehr sein

    
    """
    
    #c = Counter() #general words
    #hash_c = Counter() # hashtags
    at_c = Counter() #replies to 
    
    
    for tweet in tweets:
        for word in re.findall("@\w+", tweet["tweet"]["full_text"]):
            at_c[word.lower()] += 1

            
    counter50users = at_c.most_common(50)

    top50users = pd.DataFrame(counter50users)
    top50users.rename(columns={0:"Nutzer", 1:"Häufigkeit"}, inplace=True)
    top50users.set_index("Nutzer", inplace=True)
    top50users.to_csv(str(name)+'_top50users.csv')
    
       # Ab hier die Plots
    
    ## Words
    words = list(zip(*counter50users))[0] # Word
    counters = list(zip(*counter50users))[1] # Counter
    x_pos = np.arange(len(words)) 
    
    plt.bar(x_pos, counters,align='center')
    plt.xticks(x_pos, words,rotation='vertical', fontsize=6) 
   # plt.figure(figsize=(15, 20))
    plt.savefig(str(name)+'_top50users.png')

# %% [markdown]
# #### Funktion, die die häufigsten Wörter nach Jahr sortiert und als csv speichert

# %%
def count_words_by_year(tweets, name):
      
    """
    dict mit Jahr und Wörtern
    key: jahr
    value: wörter und verwendung
    """
    words_by_year = {}
    years = []
    for tweet in tweets:
        year = tweet["timestamp"].strftime("%Y")
        years.append(year)
    
    years = sorted(list(set(years)))
    print(years)
    
    filter_list = get_users(tweets) + get_hashtags(tweets)
    
    for year in years:
        c = Counter()
        for tweet in tweets:
            if year == tweet["timestamp"].strftime("%Y"):
                for word in get_words(tweet["tweet"]["full_text"]):
                    if word not in stopwords:
                        if word not in stopworte:
                            if word not in filter_list:
                                c[word] += 1
        words_by_year[year] = c
    #return(words_by_year)

    a = {}
    for key in words_by_year:
       # print(key)
       # print(words_by_year_laeri[key].most_common(20))
        a[key] = words_by_year[key].most_common(20)
    a = pd.DataFrame(a)
    a.reindex(sorted(a.columns), axis=1)
    a.to_csv(str(name)+'_words_by_year.csv')

# %% [markdown]
# ## Resultate

# %% [markdown]
# ### Patrick Karpiczenko

# %%
tweets_karpi = load_tweets_from_js("archiv_karpi/data/tweets.js")
# Out:
# Loaded 15440 tweets

# %%
keys_list = ["full_text","favorite_count","created_at","retweet_count"]

tweet_dict_karpi = create_custom_dictionary(tweets_karpi, keys_list)

# %%
df_karpi = create_pandas_dataframe(tweet_dict_karpi)

# %%
analysis_and_save(df_karpi,"karpi")
# Out:
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_5691/1244550010.py:23: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_month = df.groupby(pd.Grouper(freq='M')).sum()
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_5691/1244550010.py:24: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_day = df.groupby(pd.Grouper(freq='d')).sum()

# %%
dataframe_days_months_heatmap(tweets_karpi)
# Out:
# <style type="text/css">
# #T_5d23a_row0_col0, #T_5d23a_row0_col1, #T_5d23a_row0_col4, #T_5d23a_row0_col5, #T_5d23a_row0_col6, #T_5d23a_row9_col0, #T_5d23a_row9_col1, #T_5d23a_row9_col4, #T_5d23a_row9_col6, #T_5d23a_row10_col6, #T_5d23a_row11_col3, #T_5d23a_row11_col6, #T_5d23a_row12_col5, #T_5d23a_row12_col6, #T_5d23a_row13_col0, #T_5d23a_row13_col6, #T_5d23a_row15_col1, #T_5d23a_row15_col3, #T_5d23a_row15_col6, #T_5d23a_row16_col0, #T_5d23a_row16
_col17, #T_d8f5f_row10_col20, #T_d8f5f_row10_col21, #T_d8f5f_row10_col22, #T_d8f5f_row10_col23, #T_d8f5f_row11_col0, #T_d8f5f_row11_col1, #T_d8f5f_row11_col2, #T_d8f5f_row11_col3, #T_d8f5f_row11_col4, #T_d8f5f_row11_col5, #T_d8f5f_row11_col6, #T_d8f5f_row11_col9, #T_d8f5f_row11_col10, #T_d8f5f_row11_col11, #T_d8f5f_row11_col12, #T_d8f5f_row11_col15, #T_d8f5f_row11_col16, #T_d8f5f_row11_col17, #T_d8f5f_row11_col18, #T_d8f5f_row11_col20, #T_d8f5f_row11_col21, #T_d8f5f_row11_col22, #T_d8f5f_row11_col23, #T_d8f5f_row12_col1, #T_d8f5f_row12_col2, #T_d8f5f_row12_col3, #T_d8f5f_row12_col4, #T_d8f5f_row12_col5, #T_d8f5f_row12_col6, #T_d8f5f_row12_col7, #T_d8f5f_row12_col8, #T_d8f5f_row12_col9, #T_d8f5f_row12_col11, #T_d8f5f_row12_col12, #T_d8f5f_row12_col15, #T_d8f5f_row12_col16, #T_d8f5f_row12_col18, #T_d8f5f_row12_col19, #T_d8f5f_row12_col20, #T_d8f5f_row12_col22, #T_d8f5f_row12_col23, #T_d8f5f_row13_col0, #T_d8f5f_row13_col1, #T_d8f5f_row13_col2, #T_d8f5f_row13_col3, #T_d8f5f_row13_col4, #T_d8f5f_row13_col5, #T_d8f5f_row13_col6, #T_d8f5f_row13_col7,  ...

# %%
count_and_plot_top50words("karpi", tweets_karpi)

# %%
count_and_plot_top50users("karpi", tweets_karpi)

# %%
count_and_plot_top50hashtags("karpi", tweets_karpi)

# %%
count_words_by_year(tweets_karpi,"karpi")
# Out:
# ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %% [markdown]
# ### Andri Silberschmidt

# %%
tweets_silberschmidt = load_tweets_from_js("archiv_silberschmidt/data/tweets.js")
# Out:
# Loaded 4008 tweets

# %%
keys_list = ["full_text","favorite_count","created_at","retweet_count"]

tweet_dict_silberschmidt = create_custom_dictionary(tweets_silberschmidt, keys_list)

# %%
df_silberschmidt = create_pandas_dataframe(tweet_dict_silberschmidt)

# %%
analysis_and_save(df_silberschmidt, "silberschmidt")
# Out:
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_1050/747599331.py:23: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_month = df.groupby(pd.Grouper(freq='M')).sum()
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_1050/747599331.py:24: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_day = df.groupby(pd.Grouper(freq='d')).sum()

# %%
dataframe_days_months_heatmap(tweets_silberschmidt)
# Out:
# <style type="text/css">
# #T_4f3a9_row0_col0, #T_4f3a9_row0_col1, #T_4f3a9_row0_col2, #T_4f3a9_row0_col3, #T_4f3a9_row0_col4, #T_4f3a9_row0_col5, #T_4f3a9_row0_col6, #T_4f3a9_row1_col0, #T_4f3a9_row1_col1, #T_4f3a9_row1_col2, #T_4f3a9_row1_col3, #T_4f3a9_row1_col4, #T_4f3a9_row1_col5, #T_4f3a9_row1_col6, #T_4f3a9_row2_col0, #T_4f3a9_
10, #T_cc297_row8_col11, #T_cc297_row8_col12, #T_cc297_row8_col13, #T_cc297_row8_col17, #T_cc297_row8_col19, #T_cc297_row8_col23, #T_cc297_row9_col0, #T_cc297_row9_col1, #T_cc297_row9_col2, #T_cc297_row9_col3, #T_cc297_row9_col4, #T_cc297_row9_col5, #T_cc297_row9_col6, #T_cc297_row9_col9, #T_cc297_row9_col21, #T_cc297_row9_col22, #T_cc297_row10_col0, #T_cc297_row10_col1, #T_cc297_row10_col2, #T_cc297_row10_col3, #T_cc297_row10_col4, #T_cc297_row10_col5, #T_cc297_row10_col6, #T_cc297_row10_col7, #T_cc297_row10_col8, #T_cc297_row10_col9, #T_cc297_row10_col10, #T_cc297_row10_col13, #T_cc297_row10_col14, #T_cc297_row10_col15, #T_cc297_row10_col19, #T_cc297_row10_col21, #T_cc297_row ...

# %%
count_and_plot_top50words("silberschmidt", tweets_silberschmidt)

# %%
count_and_plot_top50users("silberschmidt", tweets_silberschmidt)

# %%
count_and_plot_top50hashtags("silberschmidt", tweets_silberschmidt)

# %% [markdown]
# **Andri Silberschmidt hat alte Tweets zum Teil gelöscht** deshalb gibt es nicht für alle Jahre ein Top20. Workaround: Zuerst Dict basteln, dann alte Jahre löschen und erst danach ein Pandas-Dataframe erstellen

# %%
words_by_year = {}
def count_words_by_year_return_dict(tweets):
      
    """
    dict mit Jahr und Wörtern
    key: jahr
    value: wörter und verwendung
    """
    years = []
    for tweet in tweets:
        year = tweet["timestamp"].strftime("%Y")
        years.append(year)
    
    years = sorted(list(set(years)))
    print(years)
    
    filter_list = get_users(tweets) + get_hashtags(tweets)

    
    for year in years:
        c = Counter()
        for tweet in tweets:
            if year == tweet["timestamp"].strftime("%Y"):
                for word in get_words(tweet["tweet"]["full_text"]):
                    if word not in stopwords:
                        if word not in stopworte:
                            if word not in filter_list:
                                c[word] += 1
        words_by_year[year] = c
    return(words_by_year)

# %%
df_words_years_silberschmidt = count_words_by_year_return_dict(tweets_silberschmidt)
# Out:
# ['2013', '2014', '2015', '2016', '2018', '2019', '2020', '2021', '2022']

# %%
a = {}
for key in df_words_years_silberschmidt:
   # print(key)
   # print(words_by_year_laeri[key].most_common(20))
    if key > "2017":
        a[key] = words_by_year[key].most_common(20)
a = pd.DataFrame(a)
a.reindex(sorted(a.columns), axis=1)
#return(a)

df_ab2018_words_years_silberschmidt = a
df_ab2018_words_years_silberschmidt.to_csv("silberschmidt_wörter_pro_jahr.csv")

# %% [markdown]
# ### Patrizia Laeri

# %%
tweets_laeri = load_tweets_from_js("data_twitter_laeri/tweets.js")
# Out:
# Loaded 5159 tweets

# %%
keys_list = ["full_text","favorite_count","created_at","retweet_count"]

tweet_dict_laeri = create_custom_dictionary(tweets_laeri, keys_list)

# %%
df_laeri = create_pandas_dataframe(tweet_dict_laeri)

# %%
analysis_and_save(df_laeri, "laeri")
# Out:
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_1962/747599331.py:23: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_month = df.groupby(pd.Grouper(freq='M')).sum()
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_1962/747599331.py:24: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_day = df.groupby(pd.Grouper(freq='d')).sum()

# %%
dataframe_days_months_heatmap(tweets_laeri)
# Out:
# <style type="text/css">
# #T_db658_row0_col0, #T_db658_row61_col0, #T_db658_row63_col0, #T_db658_row64_col0, #T_db658_row74_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_db658_row0_col1, #T_db658_row0_col2, #T_db658_row0_col3, #T_db658_row0_col4, #T_db658_row0_col5, #T_db658_row0_col6, #T_db658_row4_col5, #T_db658_row6_col5, #T_db658_row6_col6, #T_db658_row9_col6, #T_db658_row10_col5, #T_db658_row14_col5, #T_db658_row45_col6, #T_db658_row62_col0, #T_db658_row70_col6, #T_db658_row71_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_db658_row1_col0, #T_db658_row3_col0, #T_db658_row12_col0, #T_db658_row14_col0, #T_db658_row41_col0, #T_db658_row44_col0, #T_db658_row53_col0, #T_db658_row67_col0, #T_db658_row71_col0, #T_db658_row78_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_db658_row1_col1, #T_db658_row17_col1, #T_db658_row25_col1, #T_db658_row26_col1, #T_db658_row27_col1, #T_db658_row41_col1, #T_db658_row56_col1, #T_db658_row67_col1, #T_db658_row68_col6, #T_db658_row72_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_db658_row1_col2, #T_db658_row4_col2, #T_db658_row5_col2, #T_db658_row43_col0, #T_db658_row69_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_db658_row1_col3, #T_db658_row7_col3, #T_db658_row12_col3, #T_db658_row63_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_db658_row1_col4 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_db658_row1_col5, #T_db658_row5_col5, #T_db658_row7_col5, #T_db658_row19_col5, #T_db658_row21_col5, #T_db658_row25_col5, #T_db658_row27_col5, #T_db658_row28_col5, #T_db658_row31_col5, #T_db658_row32_col5, #T_db658_row33_col5, #T_db658_row43_col5, #T_db658_row62_col5, #T_db658_row63_col5, #T_db658_row68_col5, #T_db658_row78_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_db658_row1_col6, #T_db658_row3_col1, #T_db658_row4_col1, #T_db658_row5_col1, #T_db658_row8_col3, #T_db658_row8_col6, #T_db658_row11_col3, #T_db658_row11_col6, #T_db658_row12_col6, #T_db658_row19_col6, #T_db658_row26_col3, #T_db658_row28_col6, #T_db658_row31_col6, #T_db658_row36_col6, #T_db658_row40_col1, #T_db658_row40_col3, #T_db658_row44_col6, #T_db658_row45_col1, #T_db658_row52_col6, #T_db658_row55_col6, #T_db658_row57_col6, #T_db658_row58_col6, #T_db658_row64_col1, #T_db658_row64_col6, #T_db658_row66_col6, #T_db658_row69_col1, #T_db658_row71_col6, #T_db658_row72_col3, #T_db658_row78_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_db658_row2_col0, #T_db658_row5_col0, #T_db658_row7_col0, #T_db658_row68_col0, #T_db658_row72_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_db658_row2_col1, #T_db658_row10_col1, #T_db658_row15_col6, #T_db658_row27_col6, #T_db658_row30_col6, #T_db658_row39_col1, #T_db658_row41_col6, #T_db658_row50_col6, #T_db658_row51_col6, #T_db658_row52_col1, #T_db658_row73_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_db658_row2_col2, #T_db658_row14_col2, #T_db658_row45_col2, #T_db658_row62_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_db658_row2_col3, #T_db658_row6_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_db658_row2_col4, #T_db658_row61_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T
count_words_by_year(tweets_laeri, "laeri")
# Out:
# ['2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %% [markdown]
# ### Emma Hardcroft

# %%
tweets_hardcroft = load_tweets_from_js("archive_firefox66/data/tweets.js")
# Out:
# Loaded 12441 tweets

# %%
keys_list = ["full_text","favorite_count","created_at","retweet_count"]

tweet_dict_hardcroft = create_custom_dictionary(tweets_hardcroft, keys_list)

# %%
df_hardcroft = create_pandas_dataframe(tweet_dict_hardcroft)

# %%
analysis_and_save(df_hardcroft, "hardcroft")
# Out:
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_1962/747599331.py:23: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_month = df.groupby(pd.Grouper(freq='M')).sum()
# /var/folders/6z/gpk4kkhj5jzgy7n_k5391sfh0000gn/T/ipykernel_1962/747599331.py:24: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tweets_per_day = df.groupby(pd.Grouper(freq='d')).sum()

# %%
dataframe_days_months_heatmap(tweets_hardcroft)
# Out:
# <style type="text/css">
# #T_bcb9b_row0_col0, #T_bcb9b_row68_col3, #T_bcb9b_row79_col6, #T_bcb9b_row84_col2, #T_bcb9b_row96_col3, #T_bcb9b_row124_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_bcb9b_row0_col1, #T_bcb9b_row0_col2, #T_bcb9b_row1_col1, #T_bcb9b_row1_col3, #T_bcb9b_row16_col3, #T_bcb9b_row18_col2, #T_bcb9b_row21_col2, #T_bcb9b_row28_col3, #T_bcb9b_row34_col3, #T_bcb9b_row35_col1, #T_bcb9b_row50_col1, #T_bcb9b_row57_col1, #T_bcb9b_row62_col2, #T_bcb9b_row77_col3, #T_bcb9b_row83_col1, #T_bcb9b_row87_col3, #T_bcb9b_row89_col3, #T_bcb9b_row106_col6, #T_bcb9b_row122_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_bcb9b_row0_col3, #T_bcb9b_row1_col0, #T_bcb9b_row1_col6, #T_bcb9b_row22_col5, #T_bcb9b_row35_col4, #T_bcb9b_row36_col5, #T_bcb9b_row42_col0, #T_bcb9b_row43_col4, #T_bcb9b_row44_col0, #T_bcb9b_row47_col4, #T_bcb9b_row48_col3, #T_bcb9b_row54_col0, #T_bcb9b_row56_col3, #T_bcb9b_row60_col3, #T_bcb9b_row62_col4, #T_bcb9b_row66_col5, #T_bcb9b_row75_col4, #T_bcb9b_row84_col4, #T_bcb9b_row94_col5, #T_bcb9b_row112_col0, #T_bcb9b_row120_col4, #T_bcb9b_row128_col5, #T_bcb9b_row129_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_bcb9b_row0_col4, #T_bcb9b_row18_col5, #T_bcb9b_row26_col2, #T_bcb9b_row44_col5, #T_bcb9b_row48_col2, #T_bcb9b_row57_col0, #T_bcb9b_row61_col0, #T_bcb9b_row66_col2, #T_bcb9b_row74_col1, #T_bcb9b_row77_col0, #T_bcb9b_row81_col5, #T_bcb9b_row84_col3, #T_bcb9b_row86_col4, #T_bcb9b_row89_col0, #T_bcb9b_row91_col1, #T_bcb9b_row95_col0, #T_bcb9b_row105_col6, #T_bcb9b_row113_col3, #T_bcb9b_row113_col6, #T_bcb9b_row130_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T
d687_row66_col2, #T_2d687_row67_col1, #T_2d687_row77_col1, #T_2d687_row77_col11, #T_2d687_row78_col16, #T_2d687_row79_col2, #T_2d687_row80_col1, #T_2d687_row81_col18, #T_2d687_row82_col9, #T_2d687_row84_col1, #T_2d687_row85_col16, #T_2d687_row87_col1, #T_2d687_row87_col11, #T_2d687_row87_col16, #T_2d687_row89_col16, #T_2d687_row93_col0, #T_2d687_row93_col9, #T_2d687_row94_col0, #T_2d687_row95_col1, #T_2d687_row96_col16, #T_2d687_row108_col1, #T_2d687_row111_col9, #T_2d687_row124_col16, #T_2d687_row125_col0, #T_2d687_row126_col9 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_2d687_row0_col1, #T_2d687_row38_col1, #T_2d687_row101_col9, #T_2d687_row110_col1, #T_2d687_row110_col23, #T_2d687_row119_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_2d687_row0_col2, #T_2d687_row0_col3, #T_2d687_row0_col8, #T_2d687_row0_col9, #T_2d687_row0_col10, #T_2d687_row0_col11, #T_2d687_row1_col2, #T_2d687_row1_col8, #T_2d687_row1_col9, #T_2d687_row1_col10, #T_2d687_row1_col12, #T_2d687_row2_col0, #T_2d687_row2_col1, #T_2d687_row2_col2, #T_2d687_row2_col3, #T_2d687_row2_col5, #T_2d687_row2_col7, #T_2d687_row2_col8, #T_2d687_row2_col9, #T_2d687_row2_col10, #T_2d687_row2_col11, #T_2d687_row2_col12, #T_2d687_row2_col15, #T_2d687_row2_col16, #T_2d687_row2_col17, #T_2d687_row2_col18, #T_2d687_row2_col19, #T_2d687_row2_col20, #T_2d687_row2_col21, #T_2d687_row2_col22, #T_2d687_row2_col23, #T_2d687_row3_col0, #T_2d687_row3_col1, #T_2d687_row3_col2, #T_2d687_row3_col3, #T_2d687_row3_col4, #T_2d687_row3_col6, #T_2d687_row3_col7, #T_2d687_row3_col8, #T_2d687_row3_col9, #T_2d687_row3_col10, #T_2d687_row3_col11, #T_2d687_row3_col12, #T_2d687_row3_col13, #T_2d687_row3_col14, #T_2d687_row3_col15, #T_2d687_row3_col16, #T_2d687_row3_col17, #T_2d687_row3_col18, #T_2d687_row3_col19, #T_2d687_row3_col20, #T_2d687_row3_col21, #T_2d687_row3_col22, #T_2d687_row3_col23, #T_2d687_row4_col0, #T_2d687_row4_col1, #T_2d687_row4_col2, #T_2d687_row4_col3, #T_2d687_row4_col4, #T_2d687_row4_col5, #T_2d687_row4_col6, #T_2d687_row4_col7, #T_2d687_row4_col8, #T_2d687_row4_col9, #T_2d687_row4_col10, #T_2d687_row4_col11, #T_2d687_row4_col12, #T_2d687_row4_col13, #T_2d687_row4_col14, #T_2d687_row4_col15, #T_2d687_row4_col16, #T_2d687_row4_col17, #T_2d687_row4_col18, #T_2d687_row4_col19, #T_2d687_row4_col20, #T_2d687_row4_col21, #T_2d687_row4_col22, #T_2d687_row4_col23, #T_2d687_row5_col0, #T_2d687_row5_col1, #T_2d687_row5_col2, #T_2d687_row5_col3, #T_2d687_row5_col4, #T_2d687_row5_col5, #T_2d687_row5_col6, #T_2d687_row5_col7, #T_2d687_row5_col8, #T_2d687_row5_col10, #T_2d687_row5_col11, #T_2d687_row5_col12, #T_2d687_row5_col13, #T_2d687_row5_col14, #T_2d687_row5_col15, #T_2d687_row5_col16, #T_2d687_row5_col17, #T_2d687_row5_col18, #T_2d687_row5_col19, #T_2d687_row5_col20, #T_2d687_row5_col21, #T_2d687_row5_col22, #T_2d687_row5_col23, #T_2d687_row6_col0, #T_2d687_row6_col1, #T_2d687_row6_col2, #T_2d687_row6_col3, #T_2d687_row6_col4, #T_2d687_row6_col5, #T_2d687_row6_col6, #T_2d687_row6_col7, #T_2d687_row6_col8, #T_2d687_row6_col9, #T_2d687_row6_col10, #T_2d687_row6_col11, #T_2d687_row6_col12, #T_2d687_row6_col13, #T_2d687_row6_col14, #T_2d687_row6_col15, #T_2d687_row6_col16, #T_2d687_row6_col17, #T_2d687_row6_col18, #T_2d687_row6_col19, #T_2d687_row6_col20, #T_2d687_row6_col21, #T_2d687_row6_col22, #T_2d687_row7_col0, #T_2d687_row7_col1, #T_2d687_row7_col2, #T_2d687_row7_col3, #T_2d687_row7_col4, #T_2d687_row7_col5, #T_2d687_row7_col6, #T_2d687_row7_col7, #T_2d687_row7_col8, #T_2d687_row7_col9, #T_2d687_row7_col10, #T_2d687_row7_col11, #T_2d687_row7_col12, #T_2d687_row7_col13, #T_2d687_row7_col14, #T_2d687_row7_col15, #T_2d687_row7_col16, #T_2d687_row7_col17, #T_2d687_row7_col18, #T_2d687_row7_col19, #T_2d687_row7_col20, #T_2d687_row7_col21, #T_2d687_row7_col22, #T_2d687_row7_col23, #T_2d687_row8_col0, #T_2d687_row8_col1, #T_2d687_row8_col2, #T_2d687_row8_col4, #T_2d687_row8_col5, #T_2d687_row8_col7, #T_2d687_row8_col8, #T_2d687_row8_col10, #T_2d687_row8_col11, #T_2d687_row8_col12, #T_2d687_row8_col13, #T_2d687_row8_col14, #T_2d687_row8_col15, #T_2d687_row8_col17, #T_2d687_row8_col18, #T_2d687_row8_col19, #T_2d687_row8_col20, #T_2d687_row8_col21, #T_2d687_row8_col22, #T_2d687_row8_col23, #T_2d687_row9_col0, #T_2d687_row9_col1, #T_2d687_row9_col2, #T_2d687_row9_col3, #T_2d687_row9_col4, #T_2d687_row9_col5, #T_2d687_row9_col6, #T_2d687_row9_col7, #T_2d687_row9_col8, #T_2d687_row9_col9, #T_2d687_row9_col10, #T_2d687_row9_col11, #T_2d687_row9_col12, #T_2d687_row9_col13, #T_2d687_row9_col14, #T_2d687_row9_col15, #T_2d687_row9_col16, #T_2d687_row9_col17, #T_2d687_row9_col18, #T_2d687_row9_col19, #T_2d687_row9_col20, #T_2d687_row9_col21, #T_2d687_row9_col22, #T_2d687_row9_col23, #T_2d687_row10_col0, #T_2d687_row10_col1, #T_2d6 ...

# %%
count_and_plot_top50words("hardcroft", tweets_hardcroft)

# %%
count_and_plot_top50users("hardcroft", tweets_hardcroft)

# %%
count_and_plot_top50hashtags("hardcroft", tweets_hardcroft)

# %%
count_words_by_year(tweets_hardcroft, "hardcroft")
# Out:
# ['2009', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %% [markdown]
# ## Quellen:

# %% [markdown]
# - Wichtigste Inspirationsquelle, einiges mit Bearbeitung übernommen: https://github.com/dangoldin/twitter-archive-analysis

# %% [markdown]
# ## Appendix

# %% [markdown]
# Diese Funktionen könnten für die Darstellung eventuell noch interessant sein, kopiert von https://github.com/dangoldin/twitter-archive-analysis

# %%
def by_minute(tweets):
    minutes =[]
    for tweet in tweets:
        minutes.append(tweet["timestamp"].minute)
        


    fig = plt.figure()
    ax = fig.add_subplot(111)

    n, bins = np.histogram(minutes, range(61))

    print(n, bins)

    # get the corners of the rectangles for the histogram
    left = np.array(bins[:-1])
    right = np.array(bins[1:])
    bottom = np.zeros(len(left))
    top = bottom + n

    # we need a (numrects x numsides x 2) numpy array for the path helper
    # function to build a compound path
    XY = np.array([[left, left, right, right], [bottom, top, top, bottom]]).T

    # get the Path object
    barpath = path.Path.make_compound_path_from_polys(XY)

    # make a patch out of it
    patch = patches.PathPatch(barpath, facecolor="blue", edgecolor="gray", alpha=0.8)
    ax.add_patch(patch)

    # update the view limits
    ax.set_xlim(left[0], right[-1])
    ax.set_ylim(bottom.min(), top.max())

    # plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    plt.xticks(range(0, 60), ha="center", rotation="vertical", fontsize="8")

    plt.xlabel("Minutes")
    plt.ylabel("# Tweets")
    plt.title("# of Tweets by Minute")

    # SPEICHERN
    #plt.savefig(os.path.join(out_dir, "by-hour.png"), bbox_inches=0)
    
    
    plt.show()

# %%
def by_hour(tweets, out_dir):
    hours = []
    for tweet in tweets:
        hours.append(tweet["timestamp"].hour)

    fig = plt.figure()
    ax = fig.add_subplot(111)

    n, bins = np.histogram(hours, range(25))

    print(n, bins)

    # get the corners of the rectangles for the histogram
    left = np.array(bins[:-1])
    right = np.array(bins[1:])
    bottom = np.zeros(len(left))
    top = bottom + n

    # we need a (numrects x numsides x 2) numpy array for the path helper
    # function to build a compound path
    XY = np.array([[left, left, right, right], [bottom, top, top, bottom]]).T

    # get the Path object
    barpath = path.Path.make_compound_path_from_polys(XY)

    # make a patch out of it
    patch = patches.PathPatch(barpath, facecolor="blue", edgecolor="gray", alpha=0.8)
    ax.add_patch(patch)

    # update the view limits
    ax.set_xlim(left[0], right[-1])
    ax.set_ylim(bottom.min(), top.max())

    # plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    plt.xticks(range(0, 24), ha="center")

    plt.xlabel("Hour")
    plt.ylabel("# Tweets")
    plt.title("# of Tweets by Hour")

    # SPEICHERN
    #plt.savefig(os.path.join(out_dir, "by-hour.png"), bbox_inches=0)
    
    plt.show()

# %%
def by_day_of_week(tweets, out_dir):
    dow = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
    c = Counter()
    for tweet in tweets:
        c[tweet["timestamp"].strftime("%A")] += 1
    print(c.most_common(10))

    N = len(dow)

    ind = np.arange(N)
    width = 0.9

    fig = plt.figure()
    ax = fig.add_subplot(111)

    rects1 = ax.bar(0.05 + ind, [c[d] for d in dow], width, color="b")

    ax.set_ylabel("# Tweets")
    ax.set_title("Tweets by Day of Week")
    ax.set_xticks(ind + 0.5 * width)
    ax.set_xticklabels([d[:3] for d in dow])

    #plt.savefig(os.path.join(out_dir, "by-dow.png"), bbox_inches=0)
    xplt.show()

# %%
#by_day_of_week(tweets_laeri, "outdir")
